# %%
import libs.DataAnalyze as da
import libs.DataPlotter as dp
import libs.DataRetriever as dr
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
fpv_chunk = dr.vtk_loader('fpv_1/', False)
slfm_chunk = dr.vtk_loader('slfm/', True)
# Out:
# index= 0 VELOCITY_U
# index= 1 VELOCITY_V
# index= 2 VELOCITY_W
# index= 3 PRESSURE_DP
# index= 4 MIXTURE_F
# index= 5 MIXTURE_FF
# index= 6 density
# index= 7 TEMPERATURE
# index= 8 Chi
# index= 9 drhodt
# index= 10 fltemp
# index= 11 flrho
# index= 12 gam_sgs
# index= 13 Y_C12H23
# index= 14 Y_H2
# index= 15 Y_O2
# index= 16 Y_H2O
# index= 17 Y_OH
# index= 18 Y_CO
# index= 19 Y_CO2
# index= 20 Y_N2
# index= 21 C12H23_mean
# index= 22 H2_mean
# index= 23 O2_mean
# index= 24 H2O_mean
# index= 25 OH_mean
# index= 26 CO_mean
# index= 27 CO2_mean
# index= 28 N2_mean
# index= 29 TEMPERATURE_mean
# index= 30 C12H23_rms
# index= 31 H2_rms
# index= 32 O2_rms
# index= 33 H2O_rms
# index= 34 OH_rms
# index= 35 CO_rms
# index= 36 CO2_rms
# index= 37 N2_rms
# index= 38 TEMPERATURE_rms
# index= 39 MEAN_U
# index= 40 MEAN_V
# index= 41 MEAN_W
# index= 42 VAR_U
# index= 43 VAR_V
# index= 44 VAR_W

# %%
scalars = dr.allscalar(fpv_chunk, [4, 7, 12])
slfm_scalars = dr.allscalar(slfm_chunk, [4, 7])

# %%
scalars.shape
# Out:
# (6, 2230296)

# %%
slice_10 = dr.scatterslice(scalars, 0.01)
sslice_10 = dr.scatterslice(slfm_scalars, 0.01)

# %%
fig, axes = plt.subplots(2, 1, sharex=True)

plt.subplots_adjust(hspace=0.1)
axes[0].scatter(slice_10[3], slice_10[4], alpha=0.1, s=0.1, c='black')
axes[1].scatter(sslice_10[3], sslice_10[4], alpha=0.1, s=0.1, c='black')
